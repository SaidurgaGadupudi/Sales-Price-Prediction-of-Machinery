# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('bpp_training_data.csv')

# %%
df.head(10)
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1646770     9500.0    1126363     8434         132            17      1974
# 1  1821514    14000.0    1194089    10150         132            31      1980
# 2  1505138    50000.0    1473654     4139         132            31      1978
# 3  1671174    16000.0    1327630     8591         132            31      1980
# 4  1329056    22000.0    1336053     4089         132            31      1984
# 5  1301884    23500.0    1182999     4123         132            31      1976
# 6  1379228    31000.0    1082797     7620         132            31      1986
# 7  1645390    11750.0    1527216     8202         132            31      1970
# 8  1493279    63000.0    1363756     2759         132            31      1987
# 9  1449549    13000.0    1289412     3356         132            31      1966
#
#    MachineHoursCurrentMeter  UsageBand  fiModelDesc  ...  Grouser_Type  \
# 0                        17          0         4593  ...             0
# 1                        31          0         1820  ...             0
# 2                        31          0         2348  ...             0
# 3                        31          0         1819  ...             0
# 4                        31          0         2119  ...             0
# 5                        31          0         2298  ...             0
# 6                        31          0         3126  ...             0
# 7                        31          0          979  ...             0
# 8                        31          0         2224  ...             0
# 9                        31          0           82  ...             0
#
#    Backhoe_Mounting  Blade_Type  Travel_Controls  Differential_Type  \
# 0                 1           8                6                  0
# 1                 0           0                0                  4
# 2                 1           8                6                  0
# 3                 0           0                0                  4
# 4                 1           6                5                  0
# 5                 1           8                6                  0
# 6                 0           0                0                  4
# 7                 0           0                0                  4
# 8                 1           6                6                  0
# 9                 0           0                0                  0
#
#    Steering_Controls  saleYear  saleMonth  saleDay  saleDayOfYear
# 0                  0      1989          1       17             17
# 1                  2      1989          1       31             31
# 2                  0      1989          1       31             31
# 3                  2      1989          1       31             31
# 4                  0      1989          1       31             31
# 5                  0      1989          1       31             31
# 6                  2      1989          1       31             31
# 7                  2      1989          1       31             31
# 8                  0      1989          1       31             31
# 9                  0      1989          1       31             31
#
# [10 rows x 56 columns]

# %%
x = df.drop(['SalePrice'],axis = 1)
y = df[['SalePrice']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.15,random_state = 42)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
x_train_scaled = ss.fit_transform(x_train)
x_test_scaled = ss.transform(x_test)

# %%
per_miss = df.isnull().sum() * 100/len(df)
per_miss_data = pd.DataFrame({'columns' : df.columns , 'per_missing' : per_miss})
per_miss_data
# Out:
#                                            columns  per_missing
# SalesID                                    SalesID          0.0
# MachineID                                MachineID          0.0
# ModelID                                    ModelID          0.0
# datasource                              datasource          0.0
# auctioneerID                          auctioneerID          0.0
# YearMade                                  YearMade          0.0
# MachineHoursCurrentMeter  MachineHoursCurrentMeter          0.0
# UsageBand                                UsageBand          0.0
# fiModelDesc                            fiModelDesc          0.0
# fiBaseModel                            fiBaseModel          0.0
# fiSecondaryDesc                    fiSecondaryDesc          0.0
# fiModelSeries                        fiModelSeries          0.0
# fiModelDescriptor                fiModelDescriptor          0.0
# ProductSize                            ProductSize          0.0
# fiProductClassDesc              fiProductClassDesc          0.0
# state                                        state          0.0
# ProductGroup                          ProductGroup          0.0
# ProductGroupDesc                  ProductGroupDesc          0.0
# Drive_System                          Drive_System          0.0
# Enclosure                                Enclosure          0.0
# Forks                                        Forks          0.0
# Pad_Type                                  Pad_Type          0.0
# Ride_Control                          Ride_Control          0.0
# Stick                                        Stick          0.0
# Transmission                          Transmission          0.0
# Turbocharged                          Turbocharged          0.0
# Blade_Extension                    Blade_Extension          0.0
# Blade_Width                            Blade_Width          0.0
# Enclosure_Type                      Enclosure_Type          0.0
# Engine_Horsepower                Engine_Horsepower          0.0
# Hydraulics                              Hydraulics          0.0
# Pushblock                                Pushblock          0.0
# Ripper                                      Ripper          0.0
# Scarifier                                Scarifier          0.0
# Tip_Control                            Tip_Control          0.0
# Tire_Size                                Tire_Size          0.0
# Coupler                                    Coupler          0.0
# Coupler_System                      Coupler_System          0.0
# Grouser_Tracks                      Grouser_Tracks          0.0
# Hydraulics_Flow                    Hydraulics_Flow          0.0
# Track_Type                              Track_Type          0.0
# Undercarriage_Pad_Width    Undercarriage_Pad_Width          0.0
# Stick_Length                          Stick_Length          0.0
# Thumb                                        Thumb          0.0
# Pattern_Changer                    Pattern_Changer          0.0
# Grouser_Type                          Grouser_Type          0.0
# Backhoe_Mounting                  Backhoe_Mounting          0.0
# Blade_Type                              Blade_Type          0.0
# Travel_Controls                    Travel_Controls          0.0
# Differential_Type                Differential_Type          0.0
# Steering_Controls                Steering_Controls          0.0
# saleYear                                  saleYear          0.0
# saleMonth                                saleMonth          0.0
# saleDay                                    saleDay          0.0
# saleDayOfYear                        saleDayOfYear          0.0

# %%
#Random forest

# from sklearn.ensemble import RandomForestRegressor
# regressor = RandomForestRegressor(n_estimators=10)
# regressor.fit(x_train,y_train)
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_19656/589098471.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regressor.fit(x_train,y_train)
# RandomForestRegressor(n_estimators=10)

# %%
# y_pred=regressor.predict(x_test)
# from sklearn.metrics import r2_score
# r2_score(y_test, y_pred)
# Out:
# 0.8960945727499009

# %%
# from sklearn.metrics import mean_squared_error
# from math import sqrt
# sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 7374.930906048183

# %%
#Linear Regression 

# from sklearn.linear_model import LinearRegression
# lr = LinearRegression()
# lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# y_pred=lr.predict(x_test)
# from sklearn.metrics import r2_score
# r2_score(y_test, y_pred)
# Out:
# 0.41328354608523277

# %%
# from sklearn.metrics import mean_squared_error
# from math import sqrt
# sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 17436.228037278594

# %%
#Linear Regression with regularisation
# 1)Lasso

# from sklearn.linear_model import Lasso
# lso = Lasso()
# lso.fit(x_train_scaled,y_train)

# %%
# y_pred=lso.predict(x_test_scaled)
# from sklearn.metrics import r2_score
# r2_score(y_test, y_pred)

# %%
# from sklearn.metrics import mean_squared_error
# from math import sqrt
# sqrt(mean_squared_error(y_test, y_pred))

# %%
# 2)Ridge

# from sklearn.linear_model import Ridge
# rd = Ridge()
# rd.fit(x_train_scaled,y_train)

# %%
# y_pred=rd.predict(x_test_scaled)
# from sklearn.metrics import r2_score
# r2_score(y_test, y_pred)

# %%
# from sklearn.metrics import mean_squared_error
# from math import sqrt
# sqrt(mean_squared_error(y_test, y_pred))

# %%
# Deicison tree

from sklearn import tree
dt = tree.DecisionTreeRegressor()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dt.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8132984478789236

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 9809.322734020823

# %%
#KNN

# from sklearn.neighbors import KNeighborsRegressor
# knn = KNeighborsRegressor(n_neighbors=5)
# knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
# y_pred=knn.predict(x_test)
# from sklearn.metrics import r2_score
# r2_score(y_test, y_pred)
# Out:
# 0.4062626053049301

# %%
# from sklearn.metrics import mean_squared_error
# from math import sqrt
# sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 17492.91800256702
